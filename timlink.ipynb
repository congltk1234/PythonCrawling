# %% [markdown]
# <a href="https://colab.research.google.com/github/congltk1234/PythonCrawling/blob/main/timlink.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
def checkHTTP(item, domain):
    regex = f'^({domain}).*'
    result = re.match(regex, item) is not None
    return result

    
def check_link(item):
    #regex = '^/.*(html|htm|chn|api|[/])$'
    regex = '^/.*'
    result = re.match(regex, item) is not None
    return result

# %%
domain = input('Nhập url:')
raw_page = requests.get(url)
content = BeautifulSoup(raw_page.text, "html.parser")
a_tags = content.find_all("a")
result = set()
for item in a_tags:
    link = item.get("href")
    link = str(link)
    if checkHTTP(link, domain):
      result.add(link)
    elif check_link(link):
      result.add(domain + link)
result = list(result)
for i in result:
  print(i)
# Out:
# Nhập url:https://vietnamnet.vn/
# https://vietnamnet.vn//vn/oto-xe-may/kham-pha/
# https://vietnamnet.vn//vn/thoi-su/vu-an-nhat-cuong-va-cuu-chu-tich-ha-noi-nguyen-duc-chung-708198.html
# https://vietnamnet.vn//vn/bat-dong-san/kinh-nghiem-tu-van/
# https://vietnamnet.vn//vn/doi-song/gia-dinh/nhung-kieng-ky-trong-viec-cung-ong-cong-ong-tao-706435.html?vnn_source=trangchu&vnn_medium=box-doi-song3
# https://vietnamnet.vn//vn/the-gioi/chan-dung/he-lo-nhan-vat-dung-sau-cuoc-chinh-bien-o-myanmar-710133.html?vnn_source=trangchu&vnn_medium=moinong9
# https://vietnamnet.vn//vn/giao-duc/goc-phu-huynh/
# https://vietnamnet.vn//vn/dai-hoi-dang/ong-nguyen-phu-trong-tai-dac-cu-tong-bi-thu-khoa-xiii-709740.html
# https://vietnamnet.vn//vn/giao-duc/guong-mat-tre/
# https://vietnamnet.vn//vn/kinh-doanh/vef/
# https://vietnamnet.vn//vn/thoi-su/clip-nong/
# ...
